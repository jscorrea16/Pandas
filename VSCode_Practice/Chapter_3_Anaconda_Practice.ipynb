# %%
import pandas as pd

# %%
dog_food_orders = \
pd.read_excel('Dataset/dog_food_orders.xlsx',
             engine = 'openpyxl')
dog_food_orders
# Out:
#                   product  wholesale_price   msrp  qty_ordered  qty_shipped
# 0           skippys_dream             8.99  18.38          100          100
# 1           just_the_beef             4.99  10.43          200          195
# 2        potatos_and_lamb             5.19  11.43           50           50
# 3  turkey_and_cranberries             5.98  12.00           50           50
# 4            roasted_duck             9.59  17.48           15           15

# %%
data_url = 'https://en.wikipedia.org/wiki/Wind_power'
data = pd.read_html(data_url)
data
# Out:
# [                                                   0
#  0                                Part of a series on
#  1                                 Sustainable energy
#  2  Energy conservation Arcology Building insulati...
#  3  Renewable energy Biofuel Biogas Biomass Carbon...
#  4  Sustainable transport Bicycle Cycle rickshaw E...
#  5                  Renewable energy portal  Category
#  6  .mw-parser-output .navbar{display:inline;font-...,
#                   Wind farm  Capacity (MW)        Country  Refs
#  0          Gansu Wind Farm           7965          China  [21]
#  1      Muppandal wind farm           1500          India  [22]
#  2  Alta (Oak Creek-Mojave)           1320  United States  [23]
#  3      Jaisalmer Wind Park           1064          India  [24],
#      0                                                  1
#  0 NaN  Graphs are temporarily unavailable due to tech...,
#                                                      0   1   2   3   4
# ...

# %%
data[1]
# Out:
#                  Wind farm  Capacity (MW)        Country  Refs
# 0          Gansu Wind Farm           7965          China  [21]
# 1      Muppandal wind farm           1500          India  [22]
# 2  Alta (Oak Creek-Mojave)           1320  United States  [23]
# 3      Jaisalmer Wind Park           1064          India  [24]

# %%
page_url = \
    ('https://en.wikipedia.org/w/index.php?' +
     'title=Solar_power&oldid=1022764142')
data = pd.read_html(page_url)
data
# Out:
# [                                                   0
#  0                                Part of a series on
#  1                                 Sustainable energy
#  2  Energy conservation Arcology Building insulati...
#  3  Renewable energy Biofuel Biogas Biomass Carbon...
#  4  Sustainable transport Bicycle Cycle rickshaw E...
#  5                  Renewable energy portal  Category
#  6  .mw-parser-output .navbar{display:inline;font-...,
#      Solar Electricity Generation                                \
#                              Year                  Energy (TWh)
#  0                           2004                           2.6
#  1                           2005                           3.7
#  2                           2006                           5.0
#  3                           2007                           6.8
#  4                           2008                          11.4
#  5                           2009                          19.3
# ...

# %%
solar_PV_data = data[2]
solar_PV_data
# Out:
#                                  Name        Country  Capacity MWp  \
# 0                 Pavagada Solar Park          India          2050
# 1           Tengger Desert Solar Park          China          1547
# 2                   Bhadla Solar Park          India          1515
# 3       Kurnool Ultra Mega Solar Park          India          1000
# 4  Datong Solar Power Top Runner Base          China          1000
# 5          Longyangxia Dam Solar Park          China           850
# 6               Rewa Ultra Mega Solar          India           750
# 7         Kamuthi Solar Power Project          India           648
# 8               Solar Star (I and II)  United States           579
# 9                    Topaz Solar Farm  United States           550
#
#    Generation GWh p.a.  Size km2  \
# 0                  NaN        53
# 1                  NaN        43
# 2                  NaN        40
# 3                  NaN        24
# 4                  NaN       NaN
# ...

# %%
# Text Data (Chapter 3.01)
pd.read_csv('Dataset/bike_share.csv')
# Out:
#            dteday  hr  cnt
# 0        1/1/2011   0   16
# 1        1/1/2011   1   40
# 2        1/1/2011   2   32
# 3        1/1/2011   3   13
# 4        1/1/2011   4    1
# ...           ...  ..  ...
# 17374  12/31/2012  19  119
# 17375  12/31/2012  20   89
# 17376  12/31/2012  21   90
# 17377  12/31/2012  22   61
# 17378  12/31/2012  23   49
#
# [17379 rows x 3 columns]

# %%
# Text Data (Chapter 3.01).
# Error is to be expected.

pd.read_csv('Dataset/bike_share_UCS_2_LE_BOM.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[25], line 4
#       1 # Text Data (Chapter 3.01).
#       2 # Error is to be expected.
# ----> 4 pd.read_csv('Dataset/bike_share_UCS_2_LE_BOM.csv')
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
# Text Data (Chapter 3.01).
# The following snippet uses the encoding = 'utf_16_le' parameter to read the file:

pd.read_csv('Dataset/bike_share_UCS_2_LE_BOM.csv',\
            encoding = 'utf_16_le')
# Out:
#            dteday  hr  cnt
# 0        1/1/2011   0   16
# 1        1/1/2011   1   40
# 2        1/1/2011   2   32
# 3        1/1/2011   3   13
# 4        1/1/2011   4    1
# ...           ...  ..  ...
# 17374  12/31/2012  19  119
# 17375  12/31/2012  20   89
# 17376  12/31/2012  21   90
# 17377  12/31/2012  22   61
# 17378  12/31/2012  23   49
#
# [17379 rows x 3 columns]

# %%
#  Exercise 3.02 - Text Character Encoding and Data Separators

data = pd.read_csv('Dataset/thyroid.tsv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[27], line 3
#       1 #  Exercise 3.02 - Text Character Encoding and Data Separators
# ----> 3 data = pd.read_csv('Dataset/thyroid.tsv')
#       4 data.head()
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
#  Exercise 3.02 - Text Character Encoding and Data Separators

data = pd.read_csv('Dataset/thyroid.tsv',\
                   encoding = 'utf_16_le')
data
# Out:
#      age\tsex\ton_thyroxine\tquery_on_thyroxine\ton_antithyroid_medication\tsick\tpregnant\tthyroid_surgery\tI131_treatment\tquery_hypothyroid\tquery_hyperthyroid\tlithium\tgoitre\ttumor\thypopituitary\tpsych\tTSH_measured\tTSH\tT3_measured\tT3\tTT4_measured\tTT4\tT4U_measured\tT4U\tFTI_measured\tFTI\tTBG_measured\tTBG\treferral_source\tresult\tvalue
# 0     41\tF\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\t...
# 1     23\tF\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\t...
# 2     46\tM\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\t...
# 3     70\tF\tt\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\t...
# 4     70\tF\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\t...
# ...                                                 ...
# 2795  70\tM\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\t...
# 2796  73\tM\tf\tt\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\t...
# 2797  75\tM\tf\tf\tf\tf\tf\tf\tf\tf\tt\tf\tf\tf\tf\t...
# 2798  60\tF\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\t...
# 2799  81\tF\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\tf\t...
#
# ...

# %%
#  Exercise 3.02 - Text Character Encoding and Data Separators
# Adding the separator '\t'

data = pd.read_csv('Dataset/thyroid.tsv',\
                   encoding = 'utf_16_le',\
                   sep = '\t')
data
# Out:
#      age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0     41   F            f                  f                         f    f
# 1     23   F            f                  f                         f    f
# 2     46   M            f                  f                         f    f
# 3     70   F            t                  f                         f    f
# 4     70   F            f                  f                         f    f
# ...   ..  ..          ...                ...                       ...  ...
# 2795  70   M            f                  f                         f    f
# 2796  73   M            f                  t                         f    f
# 2797  75   M            f                  f                         f    f
# 2798  60   F            f                  f                         f    f
# 2799  81   F            f                  f                         f    f
#
# ...

# %%
#  Exercise 3.02 - Text Character Encoding and Data Separators
# sqlite3
# See VSCode Folder

import pandas as pd
import sqlite3
conn = sqlite3.connect('Dataset/bike_share.db')
c = conn.cursor()
data = pd.read_csv('Dataset/bike_share_UCS_2_LE_BOM.tsv',
                  encoding = 'utf_16_le',
                  sep = '\t')
c.execute('CREATE TABLE IF NOT EXISTS RENTALS(Date,Hour,Qty)')
conn.commit()
data.to_sql("RENTALS",conn,if_exists='replace')
# Out:
# 17379
