# %% [markdown]
# <a href="https://colab.research.google.com/github/jscorrea16/Pandas/blob/main/Chapter_8_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# DataFrame Yearly Sales
# Defining a DataFrame

data_frame = pd.DataFrame({
    'Year':['2000', '2001', '2002', '2003', '2004', '2005', '2006',
            '2007', '2008', '2009', '2010', '2011', '2012', '2013',
            '2014', '2015', '2016', '2017', '2018', '2019'],
    'Sales':[4107, 6492, 1476, 8508, 7416, 2747, 1606, 7947, 9506,
             5441, 7617, 847, 4389, 3139, 7546, 3150, 4426, 4969,
             8457, 5491]})

# %%
# Display DataFrame values

data_frame
# Out:
#     Year  Sales
# 0   2000   4107
# 1   2001   6492
# 2   2002   1476
# 3   2003   8508
# 4   2004   7416
# 5   2005   2747
# 6   2006   1606
# 7   2007   7947
# 8   2008   9506
# 9   2009   5441
# 10  2010   7617
# 11  2011    847
# 12  2012   4389
# 13  2013   3139
# 14  2014   7546
# 15  2015   3150
# 16  2016   4426
# 17  2017   4969
# 18  2018   8457
# 19  2019   5491

# %%
# DataFrame as a chart

data_frame.plot()
# Out:
# <Axes: >

# %%
# Cleaner looking plot

data_frame.plot();

# %%
# Using the Year column as the x axis

data_frame.plot(x = 'Year');

# %%
# Adding a Title

data_frame.plot(x = 'Year', title = 'Yearly Sales');

# %%
# Removing the legend

data_frame.plot(x = "Year", title = "Yearly Sales", legend = False);
